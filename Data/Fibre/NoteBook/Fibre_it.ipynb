# %%
import pandas as pd
from dbfread import DBF
import os

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\communes_2024T4_v2.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2024

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2024.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2024.csv")
# Out:
# 🔍 Données brutes :
#                          ID INSEE_COM         NOM_COM INSEE_AR INSEE_DEP  \
# 0  COMMUNE_0000000009732903     55343  Montblainville        3        55
# 1  COMMUNE_0000000009738722     52502        Valleret        3        52
# 2  COMMUNE_0000000009757597     84098           Roaix        3        84
# 3  COMMUNE_0000000009741188     52053          Blaisy        1        52
# 4  COMMUNE_0000000009750703     01052      Bouligneux        2        01
#
#        NOM_DEP INSEE_REG                      NOM_REG  \
# 0        Meuse        44                    Grand Est
# 1  Haute-Marne        44                    Grand Est
# 2     Vaucluse        93  Provence-Alpes-CÃ´te d'Azur
# 3  Haute-Marne        44                    Grand Est
# 4          Ain        84        Auvergne-RhÃ´ne-Alpes
#
#                           NOM_REG_1          STATUT  ... ZTD_2013 POPULATION  \
# 0                  CC Argonne-Meuse  Commune simple  ...        0         57
# ...

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\communes_2023T4_v3.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2023

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2023.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2023.csv")
# Out:
# 🔍 Données brutes :
#   INSEE_COM             NOM_COM INSEE_AR INSEE_DEP           NOM_DEP  \
# 0     72118              Dollon        2        72            Sarthe
# 1     44069           GuÃ©rande        3        44  Loire-Atlantique
# 2     44117           Le Pallet        2        44  Loire-Atlantique
# 3     72138  Fresnay-sur-Sarthe        2        72            Sarthe
# 4     53079     Couesmes-VaucÃ©        3        53           Mayenne
#
#   INSEE_REG           NOM_REG  \
# 0        52  Pays de la Loire
# 1        52  Pays de la Loire
# 2        52  Pays de la Loire
# 3        52  Pays de la Loire
# 4        52  Pays de la Loire
#
#                                            NOM_REG_1          STATUT L_33-13  \
# 0         CC des VallÃ©es de la Braye et de l'Anille  Commune simple       0
# 1  CA de la Presqu'Ã®le de GuÃ©rande Atlantique (...  Commune simple     SFR
# 2                                 CC SÃ¨vre et Loire  Commune simple       0
# ...

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\communes_2022T4_v1.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2022

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2022.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2022.csv")
# Out:
# 🔍 Données brutes :
#                          ID INSEE_AR POPULATION orig_ogcf INSEE_COM INSEE_REG  \
# 0  BDCSURCO0000000009593003        3          0     14626     53208        52
# 1  BDCSURCO0000000009595863        1          0      9656     53206        52
# 2  BDCSURCO0000000009596196        1          0     32442     53203        52
# 3  BDCSURCO0000000009592574        3          0     23406     53204        52
# 4  BDCSURCO0000000009605612        3          0     12813     16289        75
#
#   INSEE_DEP  NOM_REG_1  ZTD_2013                  NOM_COM  ...       Dpt  \
# 0        53  200042182         0        Saint-Cyr-en-Pail  ...   Mayenne
# 1        53  245300223         0  Saint-Charles-la-ForÃªt  ...   Mayenne
# 2        53  245300223         0              Saint-Brice  ...   Mayenne
# 3        53  200042182         0  Saint-Calais-du-DÃ©sert  ...   Mayenne
# 4        16  200072049         0                Roussines  ...  Charente
#
# ...

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\communes_2021T4_v2.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2021

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2021.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2021.csv")
# Out:
# 🔍 Données brutes :
#                          ID INSEE_COM          NOM_COM INSEE_AR INSEE_DEP  \
# 0  BDCSURCO0000000009591683     50362         Moulines        1        50
# 1  BDCSURCO0000000009580703     62313  EstrÃ©e-Blanche        2        62
# 2  BDCSURCO0000000009580960     62312          EstrÃ©e        4        62
# 3  BDCSURCO0000000009589901     50361        La Mouche        1        50
# 4  BDCSURCO0000000009580872     62311       Estevelles        7        62
#
#          NOM_DEP INSEE_REG          NOM_REG  NOM_REG_1 POPULATION  ...  \
# 0         Manche        28        Normandie  200069425          0  ...
# 1  Pas-de-Calais        32  Hauts-de-France  200072460          0  ...
# 2  Pas-de-Calais        32  Hauts-de-France  200069029          0  ...
# 3         Manche        28        Normandie  200042604          0  ...
# 4  Pas-de-Calais        32  Hauts-de-France  246200364          0  ...
#
# ...

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\communes_2020T4_v5.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2020

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2020.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2020.csv")
# Out:
# 🔍 Données brutes :
#                          ID                       NOM_COM INSEE_COM  \
# 0  COMMUNE00000000000020371        Lyon 9e arrondissement     69389
# 1  COMMUNE00000000000024125      Paris 19e arrondissement     75119
# 2  COMMUNE00000000000008849  Marseille 11e arrondissement     13211
# 3  COMMUNE00000000000006974      Paris 15e arrondissement     75115
# 4  COMMUNE00000000000018163       Paris 9e arrondissement     75109
#
#            STATUT INSEE_ARR           NOM_DEP INSEE_DEP  \
# 0  Commune simple         1             RHONE        69
# 1  Commune simple         1             PARIS        75
# 2  Commune simple         3  BOUCHES-DU-RHONE        13
# 3  Commune simple         1             PARIS        75
# 4  Commune simple         1             PARIS        75
#
#                       NOM_REG INSEE_REG  CODE_EPCI  ...  ZMD_privÃ©  L_33-13  \
# 0        AUVERGNE-RHONE-ALPES        84  200046977  ...           0        0
# ...

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\2019_T4_communes_v8.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2019

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2019.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2019.csv")
# Out:
# 🔍 Données brutes :
#                          ID                       NOM_COM INSEE_COM  \
# 0  COMMUNE00000000000020371        Lyon 9e arrondissement     69389
# 1  COMMUNE00000000000024125      Paris 19e arrondissement     75119
# 2  COMMUNE00000000000008849  Marseille 11e arrondissement     13211
# 3  COMMUNE00000000000006974      Paris 15e arrondissement     75115
# 4  COMMUNE00000000000018163       Paris 9e arrondissement     75109
#
#            STATUT INSEE_ARR           NOM_DEP INSEE_DEP  \
# 0  Commune simple         1             RHONE        69
# 1  Commune simple         1             PARIS        75
# 2  Commune simple         3  BOUCHES-DU-RHONE        13
# 3  Commune simple         1             PARIS        75
# 4  Commune simple         1             PARIS        75
#
#                       NOM_REG INSEE_REG  CODE_EPCI  ...  ZMD_privÃ©  L_33-13  \
# 0        AUVERGNE-RHONE-ALPES        84  200046977  ...           0        0
# ...

# %%
# Étape 2 : Charger le fichier .dbf avec encodage correct
path = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\2018_T4_communes_V2.dbf"
table = DBF(path, encoding='latin-1', load=True)  # ou 'utf-8' si ça ne marche pas
df = pd.DataFrame(iter(table))

# Étape 3 : Vérifier les 5 premières lignes
print("🔍 Données brutes :")
print(df.head())

# Étape 4 : Voir toutes les colonnes pour repérer celle du taux de couverture fibre
print("\n📋 Colonnes disponibles :")
print(df.columns)

# Étape 5 : Résumé statistique de la variable 'couv'
print("\n📊 Statistiques de la colonne 'couv' :")
print(df["couv"].describe())

# Étape 6 : Créer la variable Fibre_it
df["Fibre_it"] = (df["couv"] >= 80).astype(int)

# Étape 7 : Vérifier le résultat
print("\n✅ Exemple après création de Fibre_it :")
print(df[["INSEE_COM", "NOM_COM", "couv", "Fibre_it"]].head(10))

# Étape 8 : Créer une version simplifiée pour export
df_clean = df[["INSEE_COM", "Fibre_it"]].copy()
df_clean["annee"] = 2018

# Étape 9 : Vérifier le fichier final
print("\n📦 Fichier final prêt à exporter :")
print(df_clean.head())

# Étape 10 : Exporter
df_clean.to_csv(r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2018.csv", index=False)
print("\n✅ Export effectué vers fibre_it_2018.csv")
# Out:
# 🔍 Données brutes :
#                          ID                       NOM_COM  \
# 0  COMMUNE00000000000020371        Lyon 9e arrondissement
# 1  COMMUNE00000000000024125      Paris 19e arrondissement
# 2  COMMUNE00000000000008849  Marseille 11e arrondissement
# 3  COMMUNE00000000000006974      Paris 15e arrondissement
# 4  COMMUNE00000000000018163       Paris 9e arrondissement
#
#                       NOM_COM_M INSEE_COM          STATUT INSEE_ARR  \
# 0        LYON-9E-ARRONDISSEMENT     69389  Commune simple         1
# 1      PARIS-19E-ARRONDISSEMENT     75119  Commune simple         1
# 2  MARSEILLE-11E-ARRONDISSEMENT     13211  Commune simple         3
# 3      PARIS-15E-ARRONDISSEMENT     75115  Commune simple         1
# 4       PARIS-9E-ARRONDISSEMENT     75109  Commune simple         1
#
#             NOM_DEP INSEE_DEP                     NOM_REG INSEE_REG  ...  \
# 0             RHONE        69        AUVERGNE-RHONE-ALPES        84  ...
# ...

# %%
# Dossier où se trouvent tous les fichiers fibre_it
folder = r"C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre"

# Liste des années à fusionner
annees = [2018, 2019, 2020, 2021, 2022, 2023, 2024]

# Liste pour stocker les petits DataFrames
all_dfs = []

# Boucle sur chaque fichier
for annee in annees:
    file_path = os.path.join(folder, f"fibre_it_{annee}.csv")  # ⚡ Attention à bien vérifier que ce sont des .csv
    try:
        df = pd.read_csv(file_path)
        df["annee"] = annee  # Juste pour être sûr d'avoir l'année
        all_dfs.append(df)
        print(f"✅ Fichier chargé : {file_path}")
    except Exception as e:
        print(f"⚠️ Erreur avec {file_path} : {e}")

# Fusionner tous les fichiers ensemble
panel_fibre = pd.concat(all_dfs, ignore_index=True)
panel_fibre = panel_fibre.sort_values(by=["INSEE_COM", "annee"]).reset_index(drop=True)

# Vérifier rapidement
print(panel_fibre.head())

# Sauvegarder le panel final
output_path = os.path.join(folder, "panel_fibre_it_2018_2024.csv")
panel_fibre.to_csv(output_path, index=False)

print(f"\n✅ Panel final exporté vers : {output_path}")
# Out:
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2018.csv
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2019.csv
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2020.csv
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2021.csv
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2022.csv
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2023.csv
# ✅ Fichier chargé : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\fibre_it_2024.csv
#   INSEE_COM  Fibre_it  annee
# 0     01001         0   2018
# 1     01001         0   2019
# 2     01001         0   2020
# 3     01001         0   2021
# 4     01001         0   2022
#
# ✅ Panel final exporté vers : C:\Users\fares\OneDrive\Desktop\Mémoire\Fibre\panel_fibre_it_2018_2024.csv
